# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <b>MY JUPYTER NOTEBOOK ON IBM WATSON STUDIO<b/>

# %% [markdown]
# ROHIT SHUKLA
# DATA SCIENTIST

# %% [markdown]
# <i> I am interested in data science because Data Science is among the top 10 in-demand jobs of 2023 in World, with an average annual salary of 85000$.<i/>

# %%
number1 = int(input('what is the first number?:'))
number2 = int(input('what is the second number?:'))
print( 'the sum of' + str(number1) + 'and' + str(number2) + 'is')                
print  (number1 + number2)
# Out:
# the sum of37and79is
# 116

# %% [markdown]
# - x
#     - y
#          - z

# %% [markdown]
# | voltage(V = IR) | current(I) | RESISTANCE(R) |
# | --- | --- | --- |
# | 100 | 20 | 5 |

# %% [markdown]
# https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedWidget/c1F5I/instructions-create-and-share-your-jupyter-notebook
